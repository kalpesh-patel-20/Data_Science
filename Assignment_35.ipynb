# %% [markdown]
# ### **Q1. Write a Python function that takes in two arrays of data and calculates the F-value for a variance ratio test. The function should return the F-value and the corresponding p-value for the test.**
#
# **Answer:**
#
# The F-value for two samples (with sample variances `s1²` and `s2²`) is calculated as:
# ```python
# F = max(s1² / s2², s2² / s1²)
# ```
#
# For example:
# ```python
# F = 2.0978, p-value = 0.0505
# ```
# This indicates a marginally non-significant difference in variances at the 5% level.
#
# ---
#
# ### **Q2. Given a significance level of 0.05 and the degrees of freedom for the numerator and denominator of an F-distribution, write a Python function that returns the critical F-value for a two-tailed test.**
#
# **Answer:**
#
# For a two-tailed F-test with `alpha = 0.05`, `df1 = 29`, and `df2 = 29`:
#
# ```python
# Lower Critical Value ≈ 0.457, Upper Critical Value ≈ 2.175
# ```
#
# ---
#
# ### **Q3. Write a Python program that generates random samples from two normal distributions with known variances and uses an F-test to determine if the variances are equal.**
#
# **Answer:**
#
# For generated samples:
# ```python
# F = 2.0978, df1 = 29, df2 = 29, p-value = 0.0505
# ```
#
# Since p ≈ 0.05, the result is on the threshold of significance.
#
# ---
#
# ### **Q4. The variances of two populations are known to be 10 and 15. A sample of 12 observations is taken from each. Conduct an F-test at the 5% level.**
#
# **Answer:**
#
# ```python
# F = 0.6667, p-value = 0.5124
# ```
# No significant difference between variances (p > 0.05).
#
# ---
#
# ### **Q5. A manufacturer claims that the variance is 0.005. A sample variance is 0.006 from 25 items. Test at 1% level.**
#
# **Answer:**
#
# ```python
# F = 1.2, p-value = 0.6587
# ```
# Fail to reject the claim. No significant difference in variance.
#
# ---
#
# ### **Q6. Write a Python function that calculates the mean and variance of an F-distribution.**
#
# **Answer (for df1 = 10, df2 = 20):**
#
# ```python
# Mean ≈ 1.111, Variance ≈ 0.4321
# ```
#
# ---
#
# ### **Q7. Two samples with variances 25 and 20, sample sizes 10 and 15. Conduct F-test at 10% level.**
#
# **Answer:**
#
# ```python
# F = 1.25, p-value = 0.6832
# ```
# No significant difference (p > 0.10).
#
# ---
#
# ### **Q8. Restaurant waiting times: A = [24, 25, 28, 23, 22, 20, 27]; B = [31, 33, 35, 30, 32, 36].**
#
# **Answer:**
#
# ```python
# F = 1.455, p-value = 0.6975
# ```
# No significant difference in variances.
#
# ---
#
# ### **Q9. Test scores: Group A = [80, 85, 90, 92, 87, 83]; Group B = [75, 78, 82, 79, 81, 84]. Test at 1% level.**
#
# **Answer:**
#
# ```python
# F = 1.944, p-value = 0.4831
# ```
# No significant difference in variance (p > 0.01).
